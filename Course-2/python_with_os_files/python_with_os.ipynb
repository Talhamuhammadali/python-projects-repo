# %% [markdown]
# ## Interacting with Operating system in python
# We will be using `os library`

# %%
import os
outputs = {}
outputs["cwd"] = os.getcwd() # current work direcotry
outputs["wd_files_and_directories"] = os.listdir() # list current directory files
outputs["path"] = os.environ.get("PATH") # System Path varible value
outputs
# Out:
# {'cwd': '/home/talhamuammad/Desktop/Git-repos/chat-assistant/python_with_os_files',
#  'wd_files_and_directories': ['csvfile.txt',
#   'requirements.txt',
#   'python_with_os.ipynb'],
#  'path': '/home/talhamuammad/Desktop/Git-repos/chat-assistant/venv/bin:/home/talhamuammad/.local/bin:/home/talhamuammad/.local/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/snap/bin:/snap/bin:/home/talhamuammad/.local/bin:/home/talhamuammad/.local/bin:/home/talhamuammad/.local/bin'}

# %%
print(os.path.exists("book.txt"))
# remove file
try:
    os.remove("book.txt")
except FileNotFoundError as fnf:
    print(fnf)

# rename file
if os.path.exists("book.txt"):
    os.rename("book.txt", "novel.txt")
# Out:
# False
# [Errno 2] No such file or directory: 'book.txt'

# %%
import datetime
# get size of file in bytes
print(os.path.getsize("requirements.txt"))
# get timestamp
tm_stamp = os.path.getatime("requirements.txt")
hm_time = datetime.datetime.fromtimestamp(tm_stamp) # human readable
print(str(hm_time))
# abspath convert file in cwd to absolute file path
print(os.path.abspath("requirements.txt"))
# Out:
# 223
# 2025-04-10 16:13:33.915297
# /home/talhamuammad/Desktop/Git-repos/chat-assistant/python_with_os_files/requirements.txt

# %%
# make directory
try:
    os.mkdir("new_dir")
except FileExistsError:
    print("Directory already exists.")
# change cwd to new
os.chdir("new_dir")
print(os.getcwd())
os.chdir("..") 
print(os.getcwd())
print(os.path.isdir("new_dir"))
# Out:
# /home/talhamuammad/Desktop/Git-repos/chat-assistant/python_with_os_files/new_dir
# /home/talhamuammad/Desktop/Git-repos/chat-assistant/python_with_os_files
# True

# %%
import os
def parent_directory():
  # Create a relative path to the parent 
  # of the current working directory 
  relative_parent = os.path.join(".", "..")
  print(relative_parent)  
  # Return the absolute path of the parent directory
  return os.path.abspath(relative_parent)

print(parent_directory())
# Out:
# ./..
# /home/talhamuammad/Desktop/Git-repos/chat-assistant

# %% [markdown]
# ## Python csv modul basics

# %%
import csv
f = open("csvfile.txt")
csv_file = csv.reader(f)
for rows in csv_file:
    print(rows)
# Out:
# ['test', 'file', 'for', 'csv']
# ['123', '33', '44', '55']

# %%
hosts = [["workstation.local", "192.168.25.46"],["webserver.cloud", "10.2.5.6"]]
if os.path.exists("hosts.csv"):
    os.remove("hosts.csv")
with open('hosts.csv', 'w') as hosts_csv:
    writer = csv.writer(hosts_csv)
    writer.writerows(hosts)

# %%
# !cat hosts.csv
# Out:
# workstation.local,192.168.25.46
# webserver.cloud,10.2.5.6

# %%
software_csv = [
    ("name","version","status","users"),
("MailTree","5.34","production",324),
("CalDoor","1.25.1","beta",22),
("Chatty Chicken","0.34","alpha",4)
]
if os.path.exists("software.csv"):
    os.remove("software.csv")
with open("software.csv", "w") as f:
    writer = csv.writer(f)
    writer.writerows(software_csv)

with open("software.csv") as f:
    reader = csv.DictReader(f)
    for row in reader:
        print(f"Software Name: {row['name']} has User count: {row['users']}")
# Out:
# Software Name: MailTree has User count: 324
# Software Name: CalDoor has User count: 22
# Software Name: Chatty Chicken has User count: 4

# %%
users = [ {"name": "Sol Mansi", "username": "solm", "department": "IT infrastructure"}, 
 {"name": "Lio Nelson", "username": "lion", "department": "User Experience Research"}, 
  {"name": "Charlie Grey", "username": "greyc", "department": "Development"}]
keys = ["name", "username", "department"]
with open('by_department.csv', 'w') as by_department:
    writer = csv.DictWriter(by_department, fieldnames=keys)
    writer.writeheader()
    writer.writerows(users)
# !cat by_department.csv
# Out:
# name,username,department
# Sol Mansi,solm,IT infrastructure
# Lio Nelson,lion,User Experience Research
# Charlie Grey,greyc,Development

# %% [markdown]
# #### Reading with DictReader
# csv.DictReader creates a dictonary from the csv with header as keys

# %%
import csv

# Create a file with data in it
def create_file(filename):
  with open(filename, "w") as file:
    file.write("name,color,type\n")
    file.write("carnation,pink,annual\n")
    file.write("daffodil,yellow,perennial\n")
    file.write("iris,blue,perennial\n")
    file.write("poinsettia,red,perennial\n")
    file.write("sunflower,yellow,annual\n")


# Read the file contents and format the information about each row
def contents_of_file(filename):
  return_string = ""

  # Call the function to create the file 
  create_file(filename)

  # Open the file
  with open(filename) as file:
    # Read the rows of the file into a dictionary
    reader = csv.DictReader(file)
    # Process each item of the dictionary
    for row in reader:
      return_string += "a {} {} is {}\n".format(row["color"], row["name"], row["type"])
  return return_string


#Call the function
print(contents_of_file("flowers.csv"))
# Out:
# a pink carnation is annual
# a yellow daffodil is perennial
# a blue iris is perennial
# a red poinsettia is perennial
# a yellow sunflower is annual

# %% [markdown]
# #### Reading using csv.reader
# csv.reader reads all the rows including the header. Therefore header has to be check and extracted

# %%
def contents_of_file(filename):
  return_string = ""

  # Call the function to create the file 
  create_file(filename)

  # Open the file
  with open(filename) as file:
    # Read the rows of the file
    rows = csv.reader(file)
    # Process each row
    next(rows)
    for row in rows:
      name, color, type = row
      # Format the return string for data rows only

      return_string += "a {} {} is {}\n".format(color, name, type)
  return return_string

#Call the function
print(contents_of_file("flowers.csv"))
# Out:
# a carnation pink is annual
# a daffodil yellow is perennial
# a iris blue is perennial
# a poinsettia red is perennial
# a sunflower yellow is annual

# %%
#!/usr/bin/env python3
import csv
import os

def read_employees(csv_file_location):
    csv.register_dialect('empDialect', skipinitialspace=True, strict=True)  
    employee_file = csv.DictReader(open(csv_file_location), dialect = 'empDialect')
    employee_list = []
    for data in employee_file:
        employee_list.append(dict(data))
    return employee_list

def process_data(employee_list):
    department_list = []
    for employee_data in employee_list:
        department_list.append(employee_data['Department'])
    department_data = {}
    for department_name in set(department_list):
        department_data[department_name] = department_list.count(department_name)
    return department_data

def write_report(dictionary, report_file):
    with open(report_file, "w+") as f:
        for k in sorted(dictionary):
            f.write(str(k) + ':' + str(dictionary[k]) + '\n')
        f.close()

employee_list = read_employees('/home/student/data/employees.csv')
dictionary = process_data(employee_list)
write_report(dictionary, '/home/student/data/report.txt')
